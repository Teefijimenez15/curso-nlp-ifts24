# %%
# !pip install watermark -q

# %%
# %load_ext watermark
# %watermark
# %watermark --iversions
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: 2025-09-24T16:58:05.753981+00:00
#
# Python implementation: CPython
# Python version       : 3.12.11
# IPython version      : 7.34.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.6.97+
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 2
# Architecture: 64bit
#
# spacy          : 3.8.7
# es_core_news_sm: 3.8.0

# %%
# !pip install spacy -q

# %%
# !python -m spacy download es_core_news_sm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 57.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

# %%
nlp = spacy.load("es_core_news_sm") #Guardamos el modelo en el objeto NLP, cambiar en lugar de "sm" por "lg"
import es_core_news_sm
nlp = es_core_news_sm.load()

# %% [markdown]
# ## Caso 1

# %%
doc = nlp(u'Yo, Matías Barreto, estoy volando hacia Buenos Aires.') #Creamos un documento, me doy cuenta que estoy trabajando con un documento y no con cadena de caracteres porque la coma tiene entidad propia,
print([w.text for w in doc])
# Out:
# ['Yo', ',', 'Matías', 'Barreto', ',', 'estoy', 'volando', 'hacia', 'Buenos', 'Aires', '.']

# %%
# Length of sentence
print("La cantidad de tokens es: ", len(doc))
# Out:
# La cantidad de tokens es:  11

# %%
# Print individual words (i.e., tokens)
print("Los tokens son: \n" + "_" * 20 + "\n")
for words in doc:
    print(words)
# Out:
# Los tokens son:
# ____________________
#
# Yo
# ,
# Matías
# Barreto
# ,
# estoy
# volando
# hacia
# Buenos
# Aires
# .

# %%
for token in doc:
  print(token.text, token.lemma_)
# Out:
# Yo yo
# , ,
# Matías Matías
# Barreto Barreto
# , ,
# estoy estar
# volando volar
# hacia hacia
# Buenos Buenos
# Aires Aires
# . .

# %%
# Iterar sobre los tokens en el documento y mostrar el texto y su etiqueta POS
for token in doc: #ACa tenemos de vuelta el tagging de posicion, lo que nos permite crear etiquetas para identificar relaciones internas entre esos token
    print(token.text, token.pos_, spacy.explain(token.pos_))
# Out:
# Yo PRON pronoun
# , PUNCT punctuation
# Matías PROPN proper noun
# Barreto PROPN proper noun
# , PUNCT punctuation
# estoy AUX auxiliary
# volando VERB verb
# hacia ADP adposition
# Buenos PROPN proper noun
# Aires PROPN proper noun
# . PUNCT punctuation

# %%
from collections import Counter

# %%
word_freq = Counter(doc) #Vemos cuantas veces aparece cada token
print(word_freq)
# Out:
# Counter({Yo: 1, ,: 1, Matías: 1, Barreto: 1, ,: 1, estoy: 1, volando: 1, hacia: 1, Buenos: 1, Aires: 1, .: 1})

# %% [markdown]
# ## Caso 2

# %%
doc = nlp(u'En abril de 2025 estaremos realizando una introducción a spaCy para trabajar conceptos basicos de PNL')
for token in doc:
  print(token.text, token.lemma_)
# Out:
# En en
# abril abril
# de de
# 2025 2025
# estaremos estarer
# realizando realizar
# una uno
# introducción introducción
# a a
# spaCy spaCy
# para para
# trabajar trabajar
# conceptos concepto
# basicos basico
# de de
# PNL PNL

# %%
from spacy.lang.es.examples import sentences
from spacy import displacy # Moved import here

doc = nlp(sentences[11]) #Es para traer ejemplos que tiene la libreria, son oraciones que ellos nos proporcionan para hacer pruebas
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# ¿Cuándo nació José de San Martín?
# ¿ PUNCT punct
# Cuándo PRON obj
# nació VERB ROOT
# José PROPN nsubj
# de ADP case
# San PROPN flat
# Martín PROPN flat
# ? PUNCT punct

# %%
word_freq = Counter(doc)
print(word_freq)
# Out:
# Counter({¿: 1, Cuándo: 1, nació: 1, José: 1, de: 1, San: 1, Martín: 1, ?: 1})

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="f89192d2bbab4b6299543205c24fa5e3-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">¿</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Cuándo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
# ...

# %% [markdown]
# ## Caso 3

# %%
from spacy import displacy

# %%
text = "Queremos viajar desde Buenos Aires a Mar del Plata y unos dias depues a La Plata"
doc = nlp(text) #Esta línea procesa el text utilizando el modelo spaCy cargado (nlp). spaCy tokeniza el texto, realiza el etiquetado de partes del habla, el análisis de dependencias y el Reconocimiento de Entidades Nombradas, almacenando los resultados en un objeto doc.
displacy.render(doc,style='ent',jupyter=True,options={'distance':200}) #Estoy pasandole el reconocimiento de entidades y las reconoce
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Queremos viajar desde
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buenos Aires
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mar del Plata
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y unos dias depues a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La Plata
# ...

# %%
text = "Su nombre es Benjamin; nació en Argentina."
doc = nlp(text)
displacy.render(doc,style='ent',jupyter=True,options={'distance':200}) #Me toma benjamin como localidad, pero si cambio el modelo nlp = spacy.load("es_core_news_sm") cambio en lugar de "sm" por "lg" eso va a cambiar, a mayor cantidad de volemnes de texto empiezan a detectar mas patrones empiezan a ser mas finas en su analisis
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Su nombre es
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benjamin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ; nació en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Argentina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>

# %%
displacy.render(doc, style='dep', jupyter=True, options={'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="e1c15fc204b4478a9d866be68c851b99-0" class="displacy" width="890" height="257.0" direction="ltr" style="max-width: none; height: 257.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">nombre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="167.0">
# ...

# %% [markdown]
# ## Caso 4

# %%
for token in nlp("Mis padres y amigos viven en Buenos Aires."):
    print(token.text)
# Out:
# Mis
# padres
# y
# amigos
# viven
# en
# Buenos
# Aires
# .

# %%
for chunk in nlp("Mis padres y amigos viven en Buenos Aires.").noun_chunks: #Chunk es la extension, tiene que ver con cuantos token procesa en simultaneo la libreria
      print(chunk.text)
# Out:
# Mis padres
# amigos
# Buenos Aires

# %% [markdown]
# ## Caso 4

# %%
from spacy.symbols import ORTH, NORM

# %%
doc = nlp(u"Estoy volando hacia Baires")
print([w.text for w in doc])
# Out:
# ['Estoy', 'volando', 'hacia', 'Baires']

# %%
from spacy.language import Language
from spacy.tokens import Token

# %% [markdown]
# Lematizacion, era que buscaba la raiz de la palabra, si yo quiero que la raiz de Baires diga Buenos Aires, lo construyo.

# %%
# Componente personalizado para asignar lemas específicos
@Language.component("custom_lemmatizer")
def custom_lemmatizer(doc):
    for token in doc:
        if token.text == "Baires":
            token.lemma_ = "Buenos Aires"
    return doc

# Remove the existing custom component if it exists
if "custom_lemmatizer" in nlp.pipe_names:
    nlp.remove_pipe("custom_lemmatizer")

# Añadir el componente al pipeline
nlp.add_pipe("custom_lemmatizer", after='lemmatizer')

# Ejemplo de texto en español
doc = nlp(u'Estoy volando a Baires')
print([w.text for w in doc])
print([w.lemma_ for w in doc])
# Out:
# ['Estoy', 'volando', 'a', 'Baires']
# ['estar', 'volar', 'a', 'Buenos Aires']
